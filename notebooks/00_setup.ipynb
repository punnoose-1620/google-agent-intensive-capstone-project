# %%
# !pip install -r requirements.txt
# Out:
# Collecting openai (from -r requirements.txt (line 1))
#   Downloading openai-2.8.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 2)) (2.32.5)
# Collecting pdfplumber (from -r requirements.txt (line 3))
#   Downloading pdfplumber-0.11.8-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#      ---------------------------------------- 43.6/43.6 kB 2.1 MB/s eta 0:00:00
# Collecting python-dotenv (from -r requirements.txt (line 4))
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting loguru (from -r requirements.txt (line 5))
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting fastapi (from -r requirements.txt (line 6))
#   Downloading fastapi-0.121.2-py3-none-any.whl.metadata (28 kB)
# Collecting uvicorn (from -r requirements.txt (line 7))
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting pytest (from -r requirements.txt (line 8))
#   Downloading pytest-9.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting tinydb (from -r requirements.txt (line 9))
#   Downloading tinydb-4.8.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting cachetools (from -r requirements.txt (line 10))
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from openai->-r requirements.txt (line 1)) (4.11.0)
# Collecting distro<2,>=1.7.0 (from openai->-r requirements.txt (line 1))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from openai->-r requirements.txt (line 1)) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai->-r requirements.txt (line 1))
#   Downloading jiter-0.12.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai->-r requirements.txt (line 1))
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
#      ---------------------------------------- 0.0/89.9 kB ? eta -:--:--
#      ---------------------------------------- 89.9/89.9 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from openai->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from openai->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from openai->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from requests->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from requests->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from requests->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from requests->-r requirements.txt (line 2)) (2025.10.5)
# Collecting pdfminer.six==20251107 (from pdfplumber->-r requirements.txt (line 3))
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber->-r requirements.txt (line 3)) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->-r requirements.txt (line 3))
#   Downloading pypdfium2-5.0.0-py3-none-win_amd64.whl.metadata (67 kB)
#      ---------------------------------------- 0.0/68.0 kB ? eta -:--:--
#      ---------------------------------------- 68.0/68.0 kB 3.6 MB/s eta 0:00:00
# Collecting cryptography>=36.0.0 (from pdfminer.six==20251107->pdfplumber->-r requirements.txt (line 3))
#   Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from loguru->-r requirements.txt (line 5)) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru->-r requirements.txt (line 5))
#   Downloading win32_setctime-1.2.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting starlette<0.50.0,>=0.40.0 (from fastapi->-r requirements.txt (line 6))
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi->-r requirements.txt (line 6))
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting click>=7.0 (from uvicorn->-r requirements.txt (line 7))
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: h11>=0.8 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from uvicorn->-r requirements.txt (line 7)) (0.16.0)
# Collecting iniconfig>=1.0.1 (from pytest->-r requirements.txt (line 8))
#   Downloading iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=22 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from pytest->-r requirements.txt (line 8)) (25.0)
# Collecting pluggy<2,>=1.5 (from pytest->-r requirements.txt (line 8))
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from pytest->-r requirements.txt (line 8)) (2.19.2)
# Requirement already satisfied: httpcore==1.* in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (1.0.9)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1))
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\punno\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber->-r requirements.txt (line 3)) (2.23)
# Downloading openai-2.8.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.0 MB 5.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.1/1.0 MB 3.3 MB/s eta 0:00:01
#    -------- ------------------------------- 0.2/1.0 MB 2.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.3/1.0 MB 1.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.3/1.0 MB 1.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.4/1.0 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.5/1.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.7/1.0 MB 1.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.7/1.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------- -------- 0.8/1.0 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 0.8/1.0 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 0.9/1.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 1.0/1.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 1.0/1.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 1.0/1.0 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.0/1.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.2 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.8-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.0 kB ? eta -:--:--
#    ---------------------------------------- 60.0/60.0 kB 1.6 MB/s eta 0:00:00
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB 5.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/5.6 MB 2.5 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/5.6 MB 2.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/5.6 MB 1.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/5.6 MB 2.1 MB/s eta 0:00:03
#    --- ------------------------------------ 0.5/5.6 MB 1.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.5/5.6 MB 1.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.6/5.6 MB 1.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.6/5.6 MB 1.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/5.6 MB 1.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/5.6 MB 1.8 MB/s eta 0:00:03
#    ------ --------------------------------- 0.9/5.6 MB 1.7 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.6 MB 1.7 MB/s eta 0:00:03
#    -------- ------------------------------- 1.2/5.6 MB 1.8 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.6 MB 1.8 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.6 MB 1.8 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.6 MB 1.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.4/5.6 MB 1.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.4/5.6 MB 1.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.4/5.6 MB 1.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.5/5.6 MB 1.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.5/5.6 MB 1.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.6 MB 1.5 MB/s eta 0:00:03
#    ------------ --------------------------- 1.7/5.6 MB 1.6 MB/s eta 0:00:03
#    -------------- ------------------------- 2.0/5.6 MB 1.7 MB/s eta 0:00:03
#    --------------- ------------------------ 2.2/5.6 MB 1.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.3/5.6 MB 1.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.4/5.6 MB 1.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.4/5.6 MB 1.9 MB/s eta 0:00:02
#    ------------------ --------------------- 2.6/5.6 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 2.7/5.6 MB 1.9 MB/s eta 0:00:02
#    -------------------- ------------------- 2.9/5.6 MB 1.9 MB/s eta 0:00:02
#    --------------------- ------------------ 3.0/5.6 MB 1.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.1/5.6 MB 2.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.3/5.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------ --------------- 3.5/5.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 3.8/5.6 MB 2.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.1/5.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.6 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 4.4/5.6 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 4.7/5.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.9/5.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 5.1/5.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 5.3/5.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  5.6/5.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 2.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 3.2 MB/s eta 0:00:00
# Downloading fastapi-0.121.2-py3-none-any.whl (109 kB)
#    ---------------------------------------- 0.0/109.2 kB ? eta -:--:--
#    ---------------------------------------- 109.2/109.2 kB 6.2 MB/s eta 0:00:00
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.1 kB ? eta -:--:--
#    ---------------------------------------- 68.1/68.1 kB 3.6 MB/s eta 0:00:00
# Downloading pytest-9.0.1-py3-none-any.whl (373 kB)
#    ---------------------------------------- 0.0/373.7 kB ? eta -:--:--
#    ---------- ----------------------------- 102.4/373.7 kB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 256.0/373.7 kB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 317.4/373.7 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 373.7/373.7 kB 2.6 MB/s eta 0:00:00
# Downloading tinydb-4.8.2-py3-none-any.whl (24 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.3 kB ? eta -:--:--
#    ---------------------------------------- 108.3/108.3 kB 3.2 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Downloading jiter-0.12.0-cp311-cp311-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.9 kB ? eta -:--:--
#    ---------------------------------------- 204.9/204.9 kB 6.3 MB/s eta 0:00:00
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
#    ---------------------------------------- 0.0/463.4 kB ? eta -:--:--
#    ---------------- ----------------------- 194.6/463.4 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  460.8/463.4 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 463.4/463.4 kB 4.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.0 MB 5.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.0 MB 4.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.0 MB 3.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 3.3 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/2.0 MB 2.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.0 MB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.0 MB 3.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.4/2.0 MB 2.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.4/2.0 MB 2.9 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/2.0 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.7/2.0 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.7 MB/s eta 0:00:00
# Downloading pypdfium2-5.0.0-py3-none-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/3.1 MB 7.3 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/3.1 MB 6.0 MB/s eta 0:00:01
#    ------- -------------------------------- 0.6/3.1 MB 4.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.6/3.1 MB 4.3 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/3.1 MB 3.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/3.1 MB 2.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.8/3.1 MB 2.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.9/3.1 MB 2.8 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 2.5 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 2.5 MB/s eta 0:00:01
#    ------------- -------------------------- 1.1/3.1 MB 2.1 MB/s eta 0:00:01
#    -------------- ------------------------- 1.2/3.1 MB 2.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.2/3.1 MB 2.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.3/3.1 MB 2.1 MB/s eta 0:00:01
#    ------------------ --------------------- 1.5/3.1 MB 2.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.5/3.1 MB 2.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.6/3.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.8/3.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.9/3.1 MB 2.2 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.1 MB 2.2 MB/s eta 0:00:01
#    --------------------------- ------------ 2.1/3.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.3/3.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 2.4/3.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.6/3.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.7/3.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.7/3.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.7/3.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.7/3.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.7/3.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.8/3.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 2.8/3.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 2.8/3.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 3.0/3.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  3.0/3.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 1.8 MB/s eta 0:00:00
# Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/74.3 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/74.3 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------------- 74.3/74.3 kB 1.0 MB/s eta 0:00:00
# Downloading win32_setctime-1.2.0-py3-none-any.whl (4.1 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: win32-setctime, typing-inspection, tinydb, python-dotenv, pypdfium2, pydantic-core, pluggy, jiter, iniconfig, distro, click, cachetools, annotated-types, annotated-doc, uvicorn, starlette, pytest, pydantic, loguru, cryptography, pdfminer.six, openai, fastapi, pdfplumber
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 cachetools-6.2.2 click-8.3.1 cryptography-46.0.3 distro-1.9.0 fastapi-0.121.2 iniconfig-2.3.0 jiter-0.12.0 loguru-0.7.3 openai-2.8.0 pdfminer.six-20251107 pdfplumber-0.11.8 pluggy-1.6.0 pydantic-2.12.4 pydantic-core-2.41.5 pypdfium2-5.0.0 pytest-9.0.1 python-dotenv-1.2.1 starlette-0.49.3 tinydb-4.8.2 typing-inspection-0.4.2 uvicorn-0.38.0 win32-setctime-1.2.0
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os
from pathlib import Path

# %%
# Print current working directory
print("Current Working Directory:")
print(os.getcwd())
print("\n" + "="*60 + "\n")

# Get project root (parent of notebooks directory)
if Path.cwd().name == 'notebooks':
    project_root = Path.cwd().parent
else:
    project_root = Path.cwd()

print(f"Project Root: {project_root}")
print("\n" + "="*60 + "\n")
# Out:
# Current Working Directory:
# C:\Users\punno\Documents\GitHub\google-agent-intensive-capstone-project
#
# ============================================================
#
# Project Root: C:\Users\punno\Documents\GitHub\google-agent-intensive-capstone-project
#
# ============================================================

# %%
# Function to print directory tree
def print_tree(directory, prefix="", max_depth=3, current_depth=0):
    """Print directory structure in tree format"""
    if current_depth >= max_depth:
        return
    
    items = sorted(directory.iterdir(), key=lambda x: (x.is_file(), x.name))
    for i, item in enumerate(items):
        is_last = i == len(items) - 1
        current_prefix = "└── " if is_last else "├── "
        print(f"{prefix}{current_prefix}{item.name}")
        
        if item.is_dir() and not item.name.startswith('.') and item.name != '__pycache__':
            extension = "    " if is_last else "│   "
            print_tree(item, prefix + extension, max_depth, current_depth + 1)

# %%
# Print project structure
print("Project Structure:")
print_tree(project_root, max_depth=3)
# Out:
# Project Structure:
# ├── .git
# ├── .ipynb_checkpoints
# ├── data
# │   └── memory_store.json
# ├── notebooks
# │   ├── 00_setup.ipynb
# │   ├── 01_agents_demo.ipynb
# │   └── 02_end_to_end_demo.ipynb
# ├── src
# │   ├── agents
# │   │   ├── evaluator_agent.py
# │   │   ├── quiz_agent.py
# │   │   ├── search_agent.py
# │   │   └── tutor_agent.py
# │   ├── tools
# │   │   ├── code_executor.py
# │   │   ├── pdf_fetcher.py
# │   │   └── web_search.py
# │   ├── agent_framework.py
# │   ├── config.py
# │   ├── memory.py
# │   └── observability.py
# ├── tests
# │   ├── test_agents.py
# │   └── test_memory.py
# ├── .env
# ├── .gitignore
# ├── Guidelines.md
# ├── LICENSE
# ├── README.md
# └── requirements.txt

# %%
# Load .env from project root (parent directory of notebooks/)
# env_path = Path(__file__).parent.parent / '.env' if '__file__' in globals() else Path('../.env')
# print(f"Environment Path: {env_path}")
# load_dotenv(dotenv_path=env_path, verbose=True)

# %%
# Load .env from project root (directory of notebooks/)
env_path = Path(__file__).parent.parent / '.env' if '__file__' in globals() else Path('.env')
print(f"Environment Path: {env_path}")
load_dotenv(dotenv_path=env_path, verbose=True, encoding='utf-16')
# Out:
# Environment Path: .env
# True

# %%
assert os.getenv("GEMINI_API_KEY") is not None, "GEMINI_API_KEY missing"
